# %% [markdown]
# <a href="https://colab.research.google.com/github/DaviFerreira0106/notebooks-inteligenciaArtificial/blob/main/Classifica%C3%A7%C3%A3o_titanic_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classificação de dados do dataset titanic com svm

# %% [markdown]
# ## Configuração do Ambiente no Google Colab

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import numpy as np

# %% [markdown]
# ## Carregamento e Exploração do Dataset

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Transformação da culuna **`sex`**

# %%
df['sex'] = np.where(df['sex'] == 'male', 0, 1)
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500        S  Third    man
# 1         1       1    1  38.0      1      0  71.2833        C  First  woman
# 2         1       3    1  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    1  35.0      1      0  53.1000        S  First  woman
# 4         0       3    0  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %% [markdown]
# ## Transformando a coluna **`embarked`**

# %%
df['embarked'] = np.where(df['embarked'] == 'S', 0, 1)
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500         0  Third    man
# 1         1       1    1  38.0      1      0  71.2833         1  First  woman
# 2         1       3    1  26.0      0      0   7.9250         0  Third  woman
# 3         1       1    1  35.0      1      0  53.1000         0  First  woman
# 4         0       3    0  35.0      0      0   8.0500         0  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %% [markdown]
# ## Transformação da coluna **`class`**

# %%
df['class'] = np.where(df['class'] == 'First', 0, 1)
df['class'] = np.where(df['class'] == 'Second', 0, 2)
df['class'] = np.where(df['class'] == 'Third', 0, 3)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S      3
# 1         1       1  female  38.0      1      0  71.2833        C      3
# 2         1       3  female  26.0      0      0   7.9250        S      3
# 3         1       1  female  35.0      1      0  53.1000        S      3
# 4         0       3    male  35.0      0      0   8.0500        S      3
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Divisão dos Dados e Padronização

# %%
x = df.drop('survived', axis=1)
y = df['survived']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

Scaler = StandardScaler()
x_train_scaler = Scaler.fit_transform(x_train)
x_test_scaler = Scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/categorical.py in astype(self, dtype, copy)
#     590             try:
# --> 591                 new_cats = new_cats.astype(dtype=dtype, copy=copy)
#     592                 fill_value = self.categories._na_value
#
# ValueError: could not convert string to float: 'First'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-aeb93dc6f08b> in <cell line: 7>()
#       5
#       6 Scaler = StandardScaler()
# ----> 7 x_train_scaler = Scaler.fit_transform(x_train)
#       8 x_test_scaler = Scaler.transform(x_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     314     @wraps(f)
# ...
