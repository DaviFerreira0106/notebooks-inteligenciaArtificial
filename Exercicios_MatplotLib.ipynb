# %% [markdown]
# <a href="https://colab.research.google.com/github/DaviFerreira0106/notebooks-inteligenciaArtificial/blob/main/Exercicios_MatplotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios de Matplotlib

# %% [markdown]
# ## 1. Crie um gráfico de linha para a função y = x3 no intervalo de x = −10 até x = 10

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100)
y = x**3

plt.plot(x, y)
plt.title('Gráfico de linha para função y = xˆ3')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.show()

# %% [markdown]
# ## 2. Plote um gráfico de dispersão para 100 pontos aleatórios com uma paleta de cores baseada nos valores de y

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y, c=y, cmap='viridis')
plt.title('Gráfico de dispersão com paleta de cores')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.colorbar(label='Valor de y')
plt.show()

# %% [markdown]
# ## 3. Gere um histograma para 500 números inteiros gerados aleatoriamente entre 0 e 100

# %%
dados = np.random.randint(0, 101, 500)

plt.hist(dados, bins=30, edgecolor='black')
plt.title('Histograma de 500 números aleatorios entre 0 e 100')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ## 4. Crie um gráfico de barras para 5 categorias com valores diferentes, colorindo cada barra de uma cor diferente

# %%
categorias = ['A','B','C','D','E']
valores = [43, 2, 54, 34, 9]

plt.bar(categorias, valores, color=['blue', 'red', 'purple', 'yellow', 'green'])
plt.title('Gráfico de Barras')
plt.xlabel('Categoria')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# ## 5. Faça um gráfico de pizza para representar as porcentagens de quatro setores de mercado com rótulos personalizados

# %%
labels = ['A','B','C','D']
sizes = [30, 45, 5, 20]

plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Gráfico de Pizza')
plt.show()

# %% [markdown]
# ## 6. Plote dois gráficos de linha em subplots diferentes: y1 = ex e y2 = log(x)

# %%
x = np.linspace(1, 10, 100)

y1 = np.exp(x)
y2 = np.log(x)

plt.subplot(2, 1, 1)
plt.plot(x, y1)
plt.title('Gráfico de linha y1 = e^x')

plt.subplot(2, 1, 2)
plt.plot(x, y2)
plt.title('Gráfico de linha y2 = log(x)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Crie um gráfico de dispersão com tamanho dos pontos variando de acordo com os valores de y

# %%
x = np.random.rand(100)
y = np.random.rand(100)

sizes = y * 100

plt.scatter(x, y, s=sizes, alpha=0.5)
plt.title('Gráfico de dispersão com tamanho variável')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.show()

# %% [markdown]
# ## 8. Plote um gráfico de linha com intervalos de confiança (sombramento) para a função y = sin(x)

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, label='Função y = sin(x)')
plt.fill_between(x, y - 0.1, y + 0.1, color='blue', alpha=0.2)
plt.title('Gráfico de linha com intervalos de confiança')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.legend()
plt.show()

# %% [markdown]
# ## 9. Adicione título, rótulos e uma grade personalizada a um gráfico de linha

# %%
x = np.linspace(0, 10, 100)
y = np.cos(x)

plt.plot(x, y, color='blue', linestyle='--', marker='o')
plt.title('Gráfico de linha com título e grade personalizada')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10. Plote três gráficos de linha em um único gráfico, cada um com uma cor e estilo de linha diferentes

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

plt.subplot(3, 1, 1)
plt.plot(x, y1, color='blue', linestyle='-')
plt.title('Gráfico Seno')

plt.subplot(3, 1, 2)
plt.plot(x, y2, color='red', linestyle='--')
plt.title('Gráfico Cosseno')

plt.subplot(3, 1, 3)
plt.plot(x, y3, color='green', linestyle=':')
plt.title('Grafico Tangente')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Crie um gráfico de barras empilhadas para três categorias com três grupos de valores

# %%
import matplotlib.pyplot as plt
import numpy as np

categorias = ['A', 'B', 'C']
valores1 = [10, 20, 30]
valores2 = [15, 25, 35]
valores3 = [40, 50, 65]

plt.bar(categorias, valores1, label='Grupo 1')
plt.bar(categorias, valores2, bottom=valores1, label='Grupo 2')

valores1 = np.array(valores1)
valores2 = np.array(valores2)

plt.bar(categorias, valores3, bottom=valores1 + valores2, label='Grupo 3')

plt.title('Gráfico de barras empilhadas')
plt.xlabel('Categorias')
plt.ylabel('Valores')
plt.legend()
plt.show()

# %% [markdown]
# ## 12. Plote um gráfico de linha com uma função quadrática e ajuste os limites do eixo para focar nos valores **`x = −5`** a **`x = 5`**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = x**2

plt.plot(x, y)
plt.title('Gráfico de linha com função quadrática')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.xlim(-5, 5)
# Out:
# (-5.0, 5.0)

# %% [markdown]
# ## 13. Gere um gráfico de dispersão 3D para 100 pontos aleatórios utilizando Matplotlib

# %%
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c=z, cmap='viridis')
plt.title('Gráfico de dispersão 3D')
plt.show()

# %% [markdown]
# ## 14. Crie um gráfico de barras horizontal para 4 categorias com valores gerados aleatoriamente.

# %%
categorias = ['A', 'B', 'C', 'D']
valores = np.random.randint(1, 10, 4)

plt.barh(categorias, valores)
plt.title('Gráfico de barras horizontal')
plt.xlabel('Valores')
plt.ylabel('Categorias')
plt.show()

# %% [markdown]
# ## 15. Plote a função **`y = 1/x`** com x variando de 1 a 100

# %%
x = np.linspace(1, 100, 100)
y = 1**x

plt.plot(x, y)
plt.title('Gráfico de linha y = 1/x')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.show()

# %% [markdown]
# ## 16. Crie um gráfico de linha com títulos para cada eixo e adicione um rótulo de texto no ponto **`x = 5`**

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title('Gráfico de linha com título')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.text(5, 0.5, 'Este é o ponto x = 5')
plt.show()

# %% [markdown]
# ## 17. Plote um gráfico de linha e salve-o como um arquivo PDF.

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title('Gráfico de linha')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')

plt.savefig('grafico.pdf')

# %% [markdown]
# ## 18.  Crie um gráfico de barras com valores positivos e negativos e use diferentes cores para cada tipo de valor

# %%
categorias = ['A', 'B', 'C', 'D']
valores_positivos = [13, 20, 15, 43]
valores_negativos = [-8, -18, -33, -47]

plt.bar(categorias, valores_positivos, color='blue')
plt.bar(categorias, valores_negativos, color='red')

plt.title('Gráfico de barras com valores positivos e negativos')
plt.xlabel('Categorias')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# ## 19.  Plote um gráfico de linha com duas séries e adicione uma legenda para diferenciá-las.

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label='Seno')
plt.plot(x, y2, label='Cosseno')
plt.title('Gráfico de linha com legenda')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.legend()
plt.show()

# %% [markdown]
# ## 20. Adicione uma grade com espaçamento personalizado a um gráfico de linha para **`y = x²`**

# %%
x = np.linspace(0, 10, 100)
y = x**2

plt.plot(x, y, linestyle='--', linewidth=0.5, marker= 'o')
plt.title('Gráfico de linha com grade personalizada')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.grid(True)
plt.show()
