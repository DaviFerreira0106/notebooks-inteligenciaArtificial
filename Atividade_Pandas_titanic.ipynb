# %% [markdown]
# <a href="https://colab.research.google.com/github/DaviFerreira0106/notebooks-inteligenciaArtificial/blob/main/Atividade_Pandas_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ATIVIDADE PROPOSTA PARA PRÁTICA

# %% [markdown]
# # 1. Remover valores ausentes da coluna embarked e substituilos pela moda

# %%
import seaborn as sns
import pandas as pd
from sklearn.impute import SimpleImputer


##Carregar dataset titanic
df = sns.load_dataset('titanic')
##Preencher valores ausentes com a moda
imputer = SimpleImputer(strategy='most_frequent')
#OBS: precisou-se utilizar o ravel() pois o imputer.fit_transform retornava uma matriz 2D e o esperado era uma 1D
df['embarked'] = imputer.fit_transform(X=df[['embarked']]).ravel()
#Printa a saída da coluna embarked
print(imputer.fit_transform(X=df[['embarked']]).ravel())
# Out:
# ['S' 'C' 'S' 'S' 'S' 'Q' 'S' 'S' 'S' 'C' 'S' 'S' 'S' 'S' 'S' 'S' 'Q' 'S'
#  'S' 'C' 'S' 'S' 'Q' 'S' 'S' 'S' 'C' 'S' 'Q' 'S' 'C' 'C' 'Q' 'S' 'C' 'S'
#  'C' 'S' 'S' 'C' 'S' 'S' 'C' 'C' 'Q' 'S' 'Q' 'Q' 'C' 'S' 'S' 'S' 'C' 'S'
#  'C' 'S' 'S' 'C' 'S' 'S' 'C' 'S' 'S' 'S' 'C' 'C' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'C' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'Q' 'S' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'S' 'S' 'C' 'C' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'Q' 'S' 'C' 'S' 'S' 'C' 'S' 'Q' 'S' 'C' 'S' 'S' 'S' 'C' 'S' 'S' 'C'
#  'Q' 'S' 'C' 'S' 'C' 'S' 'S' 'S' 'S' 'C' 'S' 'S' 'S' 'C' 'C' 'S' 'S' 'Q'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'C' 'Q' 'S' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'Q' 'S' 'S' 'C' 'S' 'S' 'C' 'S' 'S'
#  'S' 'C' 'S' 'S' 'S' 'S' 'Q' 'S' 'Q' 'S' 'S' 'S' 'S' 'S' 'C' 'C' 'Q' 'S'
#  'Q' 'S' 'S' 'S' 'S' 'C' 'S' 'S' 'S' 'C' 'Q' 'C' 'S' 'S' 'S' 'S' 'Q' 'C'
#  'S' 'S' 'C' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S'
# ...

# %% [markdown]
# # 2. Criar gráfico de contagem para as variáveis **`pclass`** e **`survived`**

# %%
sns.countplot(data=df, x='pclass', hue='survived')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 3. Aplicar o RobustScaler na coluna **`age`** e **`fare`**

# %%
from sklearn.preprocessing import RobustScaler

#Criando variável scaler
scaler = RobustScaler()
#Aplicando o scaler na coluna age
df1 = sns.load_dataset('titanic')
df1[['age', 'fare']] = scaler.fit_transform(X=df[['age', 'fare']])
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
df1
# Out:
#      survived  pclass     sex       age  sibsp  parch       fare embarked  \
# 0           0       3    male -0.335664      1      0  -0.312011        S
# 1           1       1  female  0.559441      1      0   2.461242        C
# 2           1       3  female -0.111888      0      0  -0.282777        S
# 3           1       1  female  0.391608      1      0   1.673732        S
# 4           0       3    male  0.391608      0      0  -0.277363        S
# 5           0       3    male       NaN      0      0  -0.259680        Q
# 6           0       1    male  1.454545      0      0   1.620136        S
# 7           0       3    male -1.454545      3      1   0.286744        S
# 8           1       3  female -0.055944      0      2  -0.143827        S
# 9           1       2  female -0.783217      1      0   0.676348        C
# 10          1       3  female -1.342657      1      1   0.097265        S
# 11          1       1  female  1.678322      0      0   0.523864        S
# ...

# %% [markdown]
# # 4. Criar um gráfico de dispersão entre **`fare`** e **`age`**, separado por sexo e classe

# %%
#Gráfico de dispersão
df = sns.load_dataset('titanic')
sns.scatterplot(data=df, x='fare', y='age', hue='sex', style='pclass')
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %% [markdown]
# # 5. Criar um boxplot da variável **`age`** separada por **`pclass`** e **`survived`**

# %%
#Criação de BoxPlot
sns.boxplot(data=df, x='pclass', y='age', hue='survived')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# # 8. Aplicar One-hot encoding na variável **`pclass`**

# %%
#Aplicando One-hot encoding
df = pd.get_dummies(data=df, columns=['pclass'], drop_first=True)
print(df.head())
# Out:
#    survived     sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0    male  22.0      1      0   7.2500        S  Third    man
# 1         1  female  38.0      1      0  71.2833        C  First  woman
# 2         1  female  26.0      0      0   7.9250        S  Third  woman
# 3         1  female  35.0      1      0  53.1000        S  First  woman
# 4         0    male  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone  pclass_2  pclass_3
# 0        True  NaN  Southampton    no  False     False      True
# 1       False    C    Cherbourg   yes  False     False     False
# 2       False  NaN  Southampton   yes   True     False      True
# 3       False    C  Southampton   yes  False     False     False
# 4        True  NaN  Southampton    no   True     False      True

# %% [markdown]
# # 9. Criar gráfico de disperção para as variáveis **`fare`**, **`age`** e **`pclass`** usando **`pairplot`**

# %%
df = sns.load_dataset('titanic')
#Criando gráfico de disperção usando pairplot
sns.pairplot(data=df, vars=['fare', 'age'], hue='pclass')

# %% [markdown]
# # 10. Usar metódo **`train_test_split()`** para dividir os dados em treino (70%) e teste (30%)

# %%
#Criando train_test_split()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['survived']), df['survived'], test_size=0.3,random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (623, 14) (268, 14) (623,) (268,)
